# %%
#String Assignment

# %%
#1
a= "garima"
b= "dua"
con= a+" "+b
print(con)
# Out:
# garima dua

# %%
#2
a= "garima"
b= "dua"
con= a+" "+b
print(con)  #plus operator 

sen= ["this" , "is" , "python"]
sentence= " ".join(sen)
print(sentence) #join operator
# Out:
# garima dua
# this is python

# %%
#3
name= "python"
print(name[1])
# Out:
# y

# %%
#4
name= "garima"
print(len(name))
# Out:
# 6

# %%
#5
name= "coding"
print(name.upper())
#6
print(name.lower())
# Out:
# CODING
# coding

# %%
#7
line= "this is a python class"
print(line.replace("this" , "that"))
# Out:
# that is a python class

# %%
#8
text= "python is not fun"
print(text.split())
# Out:
# ['python', 'is', 'not', 'fun']

# %%
#9
text= "python is not fun"
print(text.startswith("p"))
#10
print(text.endswith("o"))
# Out:
# True
# False

# %%
#11
line="     today is wednesday      "
print(line.strip())
# Out:
# today is wednesday

# %%
#12
text= "hello python"
print(text.find("e"))
# Out:
# 1

# %%
#13
text= "hello python"
print(text.count("l"))
# Out:
# 2

# %%
#14
line= "python"
print(line.isalpha())
# Out:
# True

# %%
#15
num= "1234"
print(num.isdigit())
# Out:
# True

# %%
#16

# %%
#17
text="python"
print(text[::-1])
# Out:
# nohtyp

# %%
#18
name= "garima"
age= "19"
print("my name is {} and I am {} years old".format(name,age))
# Out:
# my name is garima and I am 19 years old

# %%
#19
text= "python is not fun"
print(text[7:9:])
# Out:
# is

# %%
#20
